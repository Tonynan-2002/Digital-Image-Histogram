# %%
from tools import load_image, compute_histogram, plot_histogram, display_image, histogram_equalization

# %%
path = "./test_example/example_1.jpg"
img = load_image(path)
display_image(img)

# %%
histogram = compute_histogram(img)
plot_histogram(histogram, title='Original Image Histogram')

# %%
import copy

img_copy = copy.deepcopy(img)

for i in range(img.shape[-1]):
    img_copy[:,:,i] = histogram_equalization(img_copy[:,:,i])

display_image(img_copy)
