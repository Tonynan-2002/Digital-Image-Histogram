# %%
from tools import load_image, compute_histogram, plot_histogram, display_image, histogram_equalization
from tools import HistogramEqualizationPipeline

# %%
path = "./test_example/example_1.jpg"
HistogramEqualizer = HistogramEqualizationPipeline()
# Out:
# HistogramEqualizationPipeline initialized successfully.

# %%
HistogramEqualizer.load_image(path)
# Out:
# Image loaded successfully.

# %%
HistogramEqualizer.plot_histogram()

# %%
HistogramEqualizer.display_image_with_histogram()

# %%
HistogramEqualizer.display_original_vs_equalized()
# Out:
# Using global method for histogram equalization...
# Histogram equalization completed.

# %%
HistogramEqualizer.histogram_comparison()

# %%
HistogramEqualizer.image.shape
# Out:
# (3072, 4096, 3)
